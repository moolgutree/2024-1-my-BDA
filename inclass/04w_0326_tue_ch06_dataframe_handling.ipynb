# %% [markdown]
# <a href="https://colab.research.google.com/github/moolgutree/2024-1-my-BDA/blob/main/inclass/04w_0326_tue_ch06_dataframe_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# # P.32

# %% [markdown]
# ##파이썬 설치 확인

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %% [markdown]
# ##코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize_matplotlib in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)

# %% [markdown]
# ## 수업에서 사용할 데이터를 다음 깃에서 복사

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 5.94 MiB/s, done.

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.sample()
## 괄호 안 숫자만큼 랜덤으로 나옴 (없으면 1개)
# Out:
#     id  nclass  math  english  science
# 12  13       4    46       98       65

# %%
exam.query('nclass == 1')
## nclass가 1인경우만 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %% [markdown]
# # exam[조건]
# # 집에가서 연습

# %%
exam[exam['nclass'] == 1]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('math > 50')
## 수학점수가 50을 초과하는 것만 표시
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
## 영어 점수가 80점 이하인 경우
exam.query('english <= 80')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
# 1반이면서 수학 점수가 50점 이상인 경우
exam.query('nclass == 1 & math >= 50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
# 2반이면서 영어 점수가 80점 이상인 경우
exam.query('(nclass == 2) & (english >= 80)')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45

# %%
# 수학 점수가 90점 이상이거나 영어 점수가 90점 이상인 경우
exam.query('math>= 90 | english >= 90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %% [markdown]
# # 아래거 시험 예상

# %%
# 1또는 3또는 5반에 해당하면 추출
exam.query('nclass in[1, 3, 5]')
# 시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# # 연습문제 24번을 26번처럼

# %% [markdown]
# # 아래거 시험 예상

# %%
exam[exam['nclass'].isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# # 아래 타입 : 시리즈
# ## 시리즈란? : 번호랑 열을 빼온거

# %%
exam["nclass"]
# 시리즈
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# Name: nclass, dtype: int64

# %%
exam[["nclass", "math"]]
# 데이터프레임
# Out:
#     nclass  math
# 0        1    50
# 1        1    60
# 2        1    45
# 3        1    30
# 4        2    25
# 5        2    50
# 6        2    80
# 7        2    90
# 8        3    20
# 9        3    50
# 10       3    65
# 11       3    45
# 12       4    46
# 13       4    48
# 14       4    75
# 15       4    58
# 16       5    65
# 17       5    80
# 18       5    89
# 19       5    78

# %% [markdown]
# ## 추출한 행으로 데이터 만들기

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam.query('nclass == 1')

# ncalss가 2인 행 추출해 nclass에 할당
nclass2 = exam.query('nclass == 2')

# %%
nclass1["math"].mean()
# Out:
# 46.25

# %%
nclass1["math"].sum()
# Out:
# 185

# %%
nclass1.math.sum()
# Out:
# 185

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam.query('nclass == 1')

# ncalss가 2인 행 추출해 nclass에 할당
nclass2 = exam.query('nclass == 2')

# %%
# 2반 과학 점수 평균 구하기
nclass2.science.mean()
# Out:
# 58.25

# %% [markdown]
# # P.141 문제

# %% [markdown]
# ### 문자 변수를 이용해 조건에 맞는 행 추출하기

# %%
df = pd.DataFrame({'sex' : ['F', 'M', 'F', 'M'],
                   'country' : ['Korea', 'China', 'Japan', 'USA']})

# %%
# 전체 조건에 큰따옴표, 추출할 문자에 작은따옴표 사용
df.query("sex == 'F' & country == 'Korea'")
# Out:
#   sex country
# 0   F   Korea

# %%
# 전체 조건에 작은따옴표, 추출할 문자에 큰따옴표 사용
df.query('sex == "F" & country == "Korea"')
# Out:
#   sex country
# 0   F   Korea

# %% [markdown]
# ## (알아 두면 좋아요) 외부 변수를 이용해 추출하기

# %%
var = 2
exam.query('nclass == @var')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam[exam.nclass == var]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %% [markdown]
# ## (알아 두면 좋아요) 파이썬에서 사용하는 기호

# %% [markdown]
# |논리| 연산자|기능|
# |----------------|
# |
#
# 그냥 다 아는거라 패스

# %% [markdown]
# ## 메소드 df.isin()

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0]) # list나 dict형태
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %%
df.isin([0, 2])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False       True

# %% [markdown]
# # P.145

# %% [markdown]
# ## 06-3 필요한 변수만 추출하기

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['math']]
# Out:
#     math
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78

# %% [markdown]
# # **exam['math']와 exam[['math']] 차이 알기**
# 중요

# %%
exam.sample(3)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 칼람 갖고오기
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[3]
# Out:
# 'english'

# %%
exam[exam.columns[3]]
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
# 데이터 프레임으로 보고싶다
exam[[exam.columns[3]]]
# Out:
#     english
# 0        98
# 1        97
# 2        86
# 3        98
# 4        80
# 5        89
# 6        90
# 7        78
# 8        98
# 9        98
# 10       65
# 11       85
# 12       98
# 13       87
# 14       56
# 15       98
# 16       68
# 17       78
# 18       68
# 19       83

# %%
# 칼람에서 1에서부터 2까지
exam.columns[1:3]
# Out:
# Index(['nclass', 'math'], dtype='object')

# %%
# 칼람에서 1에서부터 2까지 **열 조회**
exam[[exam.columns[3]]]
# Out:
#     english
# 0        98
# 1        97
# 2        86
# 3        98
# 4        80
# 5        89
# 6        90
# 7        78
# 8        98
# 9        98
# 10       65
# 11       85
# 12       98
# 13       87
# 14       56
# 15       98
# 16       68
# 17       78
# 18       68
# 19       83

# %% [markdown]
# ## 행과 변수(열) 제거하기

# %%
exam.sample(3)
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 12  13       4    46       98       65

# %%
exam.drop(1)
## 1번 인덱스(행) 삭제 따라서 0 다음 2번이 나옴
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(1, axis=0)
# axis는 축(행)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([1, 5])
# 두개이상은 리스트 사용
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[1, 5], axis=0)
# labels는 굳이안써도 됨
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels='nclass', axis=1)
# axis 1칼람 삭제 / 여기에서도 labels 필요 없음
# Out:
#     id  math  english  science
# 0    1    50       98       50
# 1    2    60       97       60
# 2    3    45       86       78
# 3    4    30       98       58
# 4    5    25       80       65
# 5    6    50       89       98
# 6    7    80       90       45
# 7    8    90       78       25
# 8    9    20       98       15
# 9   10    50       98       45
# 10  11    65       65       65
# 11  12    45       85       32
# 12  13    46       98       65
# 13  14    48       87       12
# 14  15    75       56       78
# 15  16    58       98       65
# 16  17    65       68       98
# 17  18    80       78       90
# 18  19    89       68       87
# 19  20    78       83       58

# %%
exam.drop(['nclass', 'english'], axis=1)
# 여러 열 삭제
# Out:
#     id  math  science
# 0    1    50       50
# 1    2    60       60
# 2    3    45       78
# 3    4    30       58
# 4    5    25       65
# 5    6    50       98
# 6    7    80       45
# 7    8    90       25
# 8    9    20       15
# 9   10    50       45
# 10  11    65       65
# 11  12    45       32
# 12  13    46       65
# 13  14    48       12
# 14  15    75       78
# 15  16    58       65
# 16  17    65       98
# 17  18    80       90
# 18  19    89       87
# 19  20    78       58

# %% [markdown]
# ## 더 간단한 삭제방법

# %%
exam.drop(index=3)
#이때 index는 행의 제목
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(columns='math')
# index는 행, columns는 칼람 삭제
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(columns=['math', 'english'])
# 여러개 삭제
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %% [markdown]
# ## pandas 함수 조합하기

# %%
# nclass가 1인 행만 추출한 다음 english 추출
exam.query('nclass == 1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
exam.query('nclass == 1')[['english']]
# Out:
#    english
# 0       98
# 1       97
# 2       86
# 3       98

# %%
# math가 50 이상인 행만 추출한 다음 id, math 추출
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
# 앞 5개만 나오게
exam.query('math >= 50')[['id', 'math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
# math가 50 이상인 행만 추출한 다음 id, math 앞부분 3행까지 추출
exam.query('math >= 50')[['id', 'math']].head(3)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50

# %%
# math가 50 이상인 행만 추출한 다음 id, math 뒷부분 3행까지 추출
exam.query('math >= 50')[['id', 'math']].tail(3)
# Out:
#     id  math
# 17  18    80
# 18  19    89
# 19  20    78

# %% [markdown]
# ## 가독성 있게 코드 줄 바꾸기

# %%
# math가 50 이상인 행만 추출
# id, math 추출
# 앞부분 10행 추출

exam.query('math >= 50')[['id','math']].head(10)

# 다른버전(역슬레시 (\))
# exam.query('math >= 50') \
#           [['id','math']] \
#           .head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %% [markdown]
# ## P.151 06-4 순서대로 정렬하기

# %% [markdown]
# ### 오름차순으로 정렬하기

# %%
# math 오름차순 정렬 (보통 디폴트값 오름차순 - 작은거부터)
exam.sort_values("math").sample(3)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 12  13       4    46       98       65
# 19  20       5    78       83       58

# %%
# math 내림차순 정렬 (내림차순 - 큰거부터)
exam.sort_values("math", ascending=False).sample(3)
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 15  16       4    58       98       65

# %%
# nclass, math 오름차순 정렬
exam.sort_values(["nclass", "math"]).sample(3)
# Out:
#     id  nclass  math  english  science
# 18  19       5    89       68       87
# 0    1       1    50       98       50
# 12  13       4    46       98       65

# %%
# nclass, math 내림차순 정렬
exam.sort_values(["nclass", "math"], ascending=False).sample(3)
# Out:
#     id  nclass  math  english  science
# 10  11       3    65       65       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32

# %%
# nclass 오름차순 math 내림차순 정렬
exam.sort_values(["nclass", "math"], ascending=[True, False]).sample(3)
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 1   2       1    60       97       60
# 5   6       2    50       89       98

# %% [markdown]
# ## 06-5  파생변수 추가하기

# %%
# total 변수 추가( 맨 오른쪽에 한줄 추가됨)
exam.assign(total = exam['math'] + exam['english'] + exam['science']).sample(3)
# Out:
#    id  nclass  math  english  science  total
# 2   3       1    45       86       78    209
# 4   5       2    25       80       65    170
# 8   9       3    20       98       15    133

# %%
# 원래 exam은 안변함 (바꾸지는 않고, 반영해서 보여줌)
exam.sample(3)
# Out:
#     id  nclass  math  english  science
# 6    7       2    80       90       45
# 18  19       5    89       68       87
# 12  13       4    46       98       65

# %%
# total 변수 추가
exam['total'] = exam['math'] + exam['english'] + exam['science']
exam.sample(3) # 반영
# Out:
#     id  nclass  math  english  science  total
# 3    4       1    30       98       58    186
# 11  12       3    45       85       32    162
# 16  17       5    65       68       98    231

# %% [markdown]
# ## 여러 파생변수 한 번에 추가하기

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],       # total 추가
            mean = (exam['math'] + exam['english'] + exam['science']) / 3)  # mean 추가
# Out:
#     id  nclass  math  english  science  total       mean
# 6    7       2    80       90       45    215  71.666667
# 16  17       5    65       68       98    231  77.000000
# 15  16       4    58       98       65    221  73.666667

# %% [markdown]
# ## `df.assign()`에 `np.where()` 적용하기

# %%
import numpy as np
exam = pd.read_csv('data/exam.csv')
## 위위에서 반영된 total 없애기

# %%
import numpy as np
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fall')).sample(3)
# Out:
#     id  nclass  math  english  science  test
# 17  18       5    80       78       90  pass
# 10  11       3    65       65       65  pass
# 8    9       3    20       98       15  fall

# %% [markdown]
# ## 추가한 변수를 `pandas` 함수에 바로 활용하기

# %%
# total 변수 추가
# total 기준 정렬
exam.assign(total = exam['math'] + exam['english'] + exam['science']).sort_values('total').sample(3)
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 11  12       3    45       85       32    162
# 2    3       1    45       86       78    209

# %% [markdown]
# ## `lambda` 이용해 데이터 프레임명 줄여 쓰기

# %%
# 긴 데이터 프레임명 지정
long_name = pd.read_csv('data/exam.csv')

# long_name 직접 입력
long_name.assign(new = long_name['math'] + long_name['english'] + long_name['science']).sample(3)
# Out:
#     id  nclass  math  english  science  new
# 18  19       5    89       68       87  244
# 2    3       1    45       86       78  209
# 1    2       1    60       97       60  217

# %%
# long_name 대신 x 입력
long_name.assign(new = lambda x: x['math'] + x['english'] + x['science']).sample(3)
# Out:
#     id  nclass  math  english  science  new
# 7    8       2    90       78       25  193
# 13  14       4    48       87       12  147
# 5    6       2    50       89       98  237

# %%
# long_name 대신 y 입력
long_name.assign(new = lambda y: y['math'] + y['english'] + y['science']).sample(3)
# Out:
#    id  nclass  math  english  science  new
# 1   2       1    60       97       60  217
# 6   7       2    80       90       45  215
# 2   3       1    45       86       78  209

# %%
(lambda x, y: x+y)(10, 20)
# x에 10, y에 20넣고, 뒤의 계산한걸 반환
# Out:
# 30

# %%
fn = lambda x, y: x+y
fn(10, 20)
# 이렇게 나눠서도 가능 거의 붕어빵 틀
# Out:
# 30

# %% [markdown]
# ## 앞에서 만든 변수를 활용해 다시 변수 만들기

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
# 혹시몰라 변경되었으면 원상복구

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean  = lambda x: round(x['total'] / 3, 2)).sample(3)
# round 는 반올림(~~,2): 셋제자리에서 2제자리까지 남겨라
# Out:
#     id  nclass  math  english  science  total   mean
# 16  17       5    65       68       98    231  77.00
# 15  16       4    58       98       65    221  73.67
# 14  15       4    75       56       78    209  69.67

# %%
data = 1.125456
round(data, 2)
# round 예시
# Out:
# 1.13

# %%
exam.assign(total = lambda x: x['math'] + x['english'] + x['science'],
            mean  = lambda x: x['total'] / 3). sample(3)
# round 없는 버전
# Out:
#     id  nclass  math  english  science  total       mean
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 19  20       5    78       83       58    219  73.000000

# %%
exam.assign(total = lambda x: x['math'] + x['english'] + x['science'],
            mean  = lambda x: round(x['total'] / 3, 3)).sample(3)
# 소숫점 셋제짜리까지 반올림해서 나타내라
# Out:
#     id  nclass  math  english  science  total    mean
# 13  14       4    48       87       12    147  49.000
# 1    2       1    60       97       60    217  72.333
# 17  18       5    80       78       90    248  82.667

# %% [markdown]
# # 아래꺼 뭔가 시험나올수도있겠다싶음

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean  = exam['total'] / 3)
# 람다함수 안쓰고 바로 변수 사용 불가능
# 이거뭔가 시험 각(왜 오류뜨냐 or 채워라 등등)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-43e0a2269f10> in <cell line: 1>()
#       1 exam.assign(total = exam['math'] + exam['english'] + exam['science'],
# ----> 2             mean  = exam['total'] / 3)
#       3 # 람다함수 안쓰고 바로 변수 사용 불가능
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'total'

# %% [markdown]
# ## 학습내용 요약

# %%
## 1. 조건에 맞는 데이터만 추출하기
exam.query('english <= 80')

# 여러 조건 동시 충족
exam.query('nclass == 1 & math >= 50')

# 여러 조건 중 하나 이상 충족
exam.query('math >= 90 | english >= 90')
exam.query('nclass in [1, 3, 5]')


## 2. 필요한 변수만 추출하기
exam['math']                                 # 한 변수 추출
exam[['nclass', 'math', 'english']]          # 여러 변수 추출
exam.drop(columns = 'math')                  # 변수 제거
exam.drop(columns = ['math', 'english'])     # 여러 변수 제거


## 3. pandas 명령어 조합하기
exam.query('math >= 50')[['id', 'math']].head()


## 4. 순서대로 정렬하기
exam.sort_values('math')                     # 오름차순 정렬
exam.sort_values('math', ascending = False)  # 내림차순 정렬

# 여러 변수 기준 정렬
exam.sort_values(['nclass', 'math'], ascending = [True, False])


## 5. 파생변수 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'])

# 여러 파생변수 한 번에 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = (exam['math'] + exam['english'] + exam['science']) / 3)

# assign()에 np.where() 적용하기
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fall'))

# 추가한 변수를 pandas 코드에 바로 활용하기
exam.assign(total = exam['math'] + exam['english'] + exam['science']) \
    .sort_values('total') \
    .head()

# %% [markdown]
# `df.isin()` 추가본

# %%
df.isin([0]) # list나 dict 형태
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %%
df.isin([0, 2])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False       True

# %%
~df.isin([0, 2])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True      False

# %%
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin({'num_wings': [0, 3]})
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %% [markdown]
# 값이 Series(시리즈) 또는 DataFrame(데이터 프레임)인 경우 인덱스와 열이 일치해야 합니다. 'falcon(팔콘)'은 다른 부분의 다리 수를 기준으로 일치하지 않습니다.

# %%
other = pd.DataFrame({'num_legs': [8, 3], 'num_wings': [0, 2]},
                     index=['spider', 'falcon'])
other
# Out:
#         num_legs  num_wings
# spider         8          0
# falcon         3          2

# %%
df.isin(other)
# Out:
#         num_legs  num_wings
# falcon     False       True
# dog        False      False

# %%
s = pd.Series(['llama', 'cow', 'llama', 'beetle', 'llama', 'hippo'], name='animal')
s.isin(['cow', 'llama'])
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: animal, dtype: bool

# %%
~s.isin(['cow', 'llama'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: animal, dtype: bool

# %%
s.isin(['llama'])
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# Name: animal, dtype: bool

# %%
print(pd.Series([1]).isin(['1']))
print(pd.Series([1.1]).isin(['1.1']))
# Out:
# 0    False
# dtype: bool
# 0    False
# dtype: bool

# %%
print(pd.Series([1]).isin([1]))
print(pd.Series([1.1]).isin([1.1]))
# Out:
# 0    True
# dtype: bool
# 0    True
# dtype: bool
